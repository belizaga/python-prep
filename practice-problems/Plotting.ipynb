# %% [markdown]
# # Plotting
#
# These problems go along with the material presented in the <a href="../lectures/Basic Plotting.ipynb">Basic Plotting</a> notebook.
#
# ## Basic Problems
#
# 1. Import `matplotlib` (note not just `matplotlib.pyplot`) what version do you have?

# %%
## Code here

import matplotlib as plt
print(plt.__version__)
# Out:
# 3.9.2

# %% [markdown]
# 2. Import `matplotlib.pyplot` as `plt`.

# %%
## Code here

import matplotlib.pyplot as plt

# %% [markdown]
# 3. Plot the line $y = 4x+2$ using `plt.plot()`.

# %%
## Code here

import numpy as np

x = np.linspace(-5,5,100)
y = 4*x + 2

plt.plot(x,y)

# %% [markdown]
# 4. Plot the random walk you saved to file in <a href="Writing to File and Importing a Package.ipynb">Writing to File and Importing a Package</a>.

# %%
## Code here

import pandas as pd

random_walk = pd.read_csv("../data/random_walk.csv")

random_walk
# Out:
#      position
# 0           0
# 1          -1
# 2           0
# 3          -1
# 4          -2
# ..        ...
# 96        -14
# 97        -15
# 98        -14
# 99        -13
# 100       -14
#
# [101 rows x 1 columns]

# %%
## Code here

plt.figure(figsize = (6,4))

plt.plot(random_walk.index, random_walk.position, "ro")

plt.xlabel("Step", fontsize = 11)
plt.ylabel("Position", fontsize =11)

plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## More Advanced Problems
#
# 1. Plot two random normal histograms using `np.random.randn` to generate the random normal draws. Make one red and one blue, add a legend labeling each of the histograms.

# %%
## Code here

plt.figure(figsize = (6,4))

plt.hist(np.random.randn(100),
         color = "red",
         label = "1st draw")

plt.hist(np.random.randn(100),
         color = "blue",
         label = "2nd draw",
         alpha =.7)

plt.legend(fontsize = 14)

plt.show()

# %% [markdown]
# 2. Write a function that takes in $n$ then plots a random walk of length $n$. You may want to give the user the ability to choose the color and `linewidth` of their walk.

# %%
## Code here

def random_walk(n,col,l):
    flips = np.random.binomial(1,0.5,n)
    flips = 2*flips - 1
    x = range(-1,n,1)
    y = np.concatenate((np.zeros(1),np.cumsum(flips)))
    plt.figure(figsize = (6,4))
    plt.plot(x,y,
             color = col,
             linewidth = l)
    plt.xlabel("Step", fontsize = 11)
    plt.ylabel("Position", fontsize =11)
    return plt.show()

# %%
## Code here

random_walk(10,"red",7.0)

# %%
## Code here

random_walk(40,"green",4.0)

# %% [markdown]
# 3. Load the `iris.csv` data from the `data` folder  using `pandas`. Make a 2 x 2 subplot. In the (0,0) subplot plot the `sepal_length` on the $x$ and the `sepal_width` on the $y$, in the (1,0) subplot plot the `petal_length` on the $x$ and the `sepal_width` on the $y$, and finally in the (0,1) subplot plot the `sepal_length` on the $x$ and the `petal_width` on the $y$. Color each point by its `target`. Write the text "Iris Plot" in the (1,1) subplot.

# %%
## Code here

iris = pd.read_csv("../data/iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
## Code here

fig,axes = plt.subplots(2,2,figsize=(10,10))

axes[0,0].scatter(iris.loc[iris.target==0]["sepal_length"],iris.loc[iris.target==0]["sepal_width"],
                  color ="magenta",
                  marker = "*",
                  label = "setosa")
axes[0,0].scatter(iris.loc[iris.target==1]["sepal_length"],iris.loc[iris.target==1]["sepal_width"],
                  color ="yellow",
                  marker = "*",
                  label = "versicolor")
axes[0,0].scatter(iris.loc[iris.target==2]["sepal_length"],iris.loc[iris.target==2]["sepal_width"],
                  color ="cyan",
                  marker = "*",
                  label = "virginica")
axes[0,0].set_xlabel("Sepal length", fontsize = 11)
axes[0,0].set_ylabel("Sepal width", fontsize =11)
axes[0,0].legend(fontsize = 12)

axes[1,0].scatter(iris.loc[iris.target==0]["petal_length"],iris.loc[iris.target==0]["sepal_width"],
                  color ="magenta",
                  marker = "o",
                  label = "setosa")
axes[1,0].scatter(iris.loc[iris.target==1]["petal_length"],iris.loc[iris.target==1]["sepal_width"],
                  color ="yellow",
                  marker = "o",
                  label = "versicolor")
axes[1,0].scatter(iris.loc[iris.target==2]["petal_length"],iris.loc[iris.target==2]["sepal_width"],
                  color ="cyan",
                  marker = "o",
                  label = "virginica")
axes[1,0].set_xlabel("Petal length", fontsize = 11)
axes[1,0].set_ylabel("Sepal width", fontsize =11)
axes[1,0].legend(fontsize = 12)

axes[0,1].scatter(iris.loc[iris.target==0]["sepal_length"],iris.loc[iris.target==0]["petal_width"],
                  color ="magenta",
                  marker = "d",
                  label = "setosa")
axes[0,1].scatter(iris.loc[iris.target==1]["sepal_length"],iris.loc[iris.target==1]["petal_width"],
                  color ="yellow",
                  marker = "d",
                  label = "versicolor")
axes[0,1].scatter(iris.loc[iris.target==2]["sepal_length"],iris.loc[iris.target==2]["petal_width"],
                  color ="cyan",
                  marker = "d",
                  label = "virginica")
axes[0,1].set_xlabel("Sepal length", fontsize = 11)
axes[0,1].set_ylabel("Petal width", fontsize =11)
axes[0,1].legend(fontsize = 12)

axes[1,1].text(.2,.2,"Iris Plot",fontsize=14)

plt.show()

# %% [markdown]
# 4. Filling a circle to estimate pi.
#
# One way you can estimate pi is by drawing a random sample from a square with edges at $(1,1)$, $(-1,1)$, $(-1,-1)$ and $(1,-1)$ and finding the fraction of that sample that falls within the unit circle (a circle centered at $(0,0)$ with radius $1$).
#
# Using `np.random.random` Make an $N \times 2$ random uniform array then multiply it by $2$ and subtract $1$ (this will shift the array to be a random draw from the aforementioned square). Then use the equation for the unit circle, $x^2 + y^2 \leq 1$ to find the points in the sample that fall within the unit circle.  Plot the points within the circle using a scatter plot. Add some text to the plot that gives the size of the sample as well as the fraction of the sample within the circle times $4$ (this is the estimate of pi).

# %%
## Code here

N=10000
points = 2* np.random.random((N,2)) - 1

points
# Out:
# array([[ 0.15774712,  0.64533935],
#        [ 0.84204572,  0.08584026],
#        [-0.88260119, -0.05256304],
#        ...,
#        [-0.21743265,  0.13412952],
#        [ 0.48082244, -0.83205142],
#        [-0.84012453,  0.26123608]])

# %%
## Code here

in_points = points[points[:,0]**2 + points[:,1]**2 <= 1, :]
print("Number of points in circle:",len(in_points))
print()
result = 4* len(in_points)/len(points)
print("Our estimate for pi:", 4* len(in_points)/len(points))
# Out:
# Number of points in circle: 7908
#
# Our estimate for pi: 3.1632

# %%
## Code here

plt.figure(figsize = (6,6))

plt.scatter(in_points[:,0],in_points[:,1])

plt.text(0.5,0.92, "N =" + str(N) + "\n Estimate =" + str(result))

plt.show()

# %%
## Code here

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2023.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
